# %%
! pip install pandas
! pip install requests
! pip install plyer
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests) (2024.2.2)
# Requirement already satisfied: plyer in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.1.0)

# %%
import pandas as pd
import requests as rq
import plyer 
import datetime
import sqlite3

# %%
def error(error_message):
    current_date = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    message = f'{error_message} {current_date}'
    plyer.notification.notify(
        title='Error',
        message=message,
        app_name="Alerta"
    )

# %%
def get_response(url):
    response = rq.get(url)
    if response.status_code == 200:
        data_json = response.json()
        return data_json
    else:
        error('Tabela nao encontrada')

# %%
def get_tables(url):
    response = get_response(url)
    return response

# %%
def filter_df(df, min_population):
    return df[df['population'] > min_population]

# %%
def unstack_df(df, index_col):
    return df.set_index(index_col).unstack()

# %%
def create_df(data, columns):
    if data is None or not columns:
        return pd.DataFrame()

    df = pd.DataFrame(data)
    df['country'] = df['name'].apply(lambda x: x.get('common', ''))
    if 'capital' in df.columns:
        df['capital'] = df['capital'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x)
    print(df)
    df = df[columns]
    df_cleaned = df.dropna()
    return df_cleaned



def filter_df(df):
    def replace_empty_list(val):
        return '' if isinstance(val, list) and len(val) == 0 else val
    
    df_filtered = df.applymap(replace_empty_list)
    return df_filtered


def create_table(table_name, columns, db_name='dados_paises.db'):
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()
    col_defs = ', '.join([f'"{col}" TEXT' for col in columns])
    cursor.execute(f'CREATE TABLE IF NOT EXISTS "{table_name}" ({col_defs})')
    conn.commit()
    conn.close()
    print(f"Table '{table_name}' created successfully.")


def insert_data(table_name, data, db_name='dados_paises.db'):
    conn = sqlite3.connect(db_name,timeout=10)
    cursor = conn.cursor()
    if not data:
        print("No data to insert.")
        return
    
    placeholders = ', '.join(['?'] * len(data[0]))
    for row in data:
        cursor.execute(f'INSERT INTO "{table_name}" VALUES ({placeholders})', row)
    conn.commit()
    conn.close()
    print(f"Data inserted into '{table_name}' successfully.")


def process_data(url, table_name, columns, additional_processing=None):
    data = get_response(url)
    if data:
        df = create_df(data, columns)
        df = filter_df(df)
        create_table(table_name,columns)
        if additional_processing:
            additional_processing(df)
        insert_data(table_name, df.values.tolist())
    else:
        print(f"Failed to fetch data from {url}.")


def process_languages_countries(df, table_name='LanguagesCountries', db_name='dados_paises.db'):
    languages_countries = {}
    for index, row in df.iterrows():
        country_name = row['country']
        languages_info = row['languages']
        if isinstance(languages_info, dict):
            for language_code, language_info in languages_info.items():
                language_name = language_info if isinstance(language_info, str) else language_info.get('name', '')
                if language_name:
                    languages_countries.setdefault(language_name, []).append(country_name)
                    print(languages_countries)
    data_to_insert = [(language, country) for language, countries in languages_countries.items() for country in countries]
    insert_data(table_name, data_to_insert, db_name)

# %%
def get_countries():
    url = 'https://restcountries.com/v3.1/all?fields=name,capital,region,subregion,area,population'
    process_data(url, 'Paises', ['country','capital','region','subregion','area','population'])


def get_independent_countries():
    url = 'https://restcountries.com/v3.1/independent?status=true&fields=name,capital,region,subregion,area,population'
    process_data(url, 'Independentes', ['country','capital','region','subregion','area','population'])


def get_languages_countries():
    url = 'https://restcountries.com/v3.1/all?fields=name,languages'
    process_data(url, 'LanguagesCountries', ['languages', 'country'], additional_processing=process_languages_countries)


#get_countries()
#get_independent_countries()
get_languages_countries()
# Out:
#                                                   name  \
# 0    {'common': 'Moldova', 'official': 'Republic of...
# 1    {'common': 'United States', 'official': 'Unite...
# 2    {'common': 'Mayotte', 'official': 'Department ...
# 3    {'common': 'Nauru', 'official': 'Republic of N...
# 4    {'common': 'Mozambique', 'official': 'Republic...
# ..                                                 ...
# 245  {'common': 'Benin', 'official': 'Republic of B...
# 246  {'common': 'Japan', 'official': 'Japan', 'nati...
# 247  {'common': 'Dominican Republic', 'official': '...
# 248  {'common': 'Qatar', 'official': 'State of Qata...
# 249  {'common': 'Gabon', 'official': 'Gabonese Repu...
#
#                               languages             country
# 0                   {'ron': 'Romanian'}             Moldova
# 1                    {'eng': 'English'}       United States
# 2                     {'fra': 'French'}             Mayotte
# 3    {'eng': 'English', 'nau': 'Nauru'}               Nauru
# 4                 {'por': 'Portuguese'}          Mozambique
# ..                                  ...                 ...
# 245                   {'fra': 'French'}               Benin
# 246                 {'jpn': 'Japanese'}               Japan
# 247                  {'spa': 'Spanish'}  Dominican Republic
# 248                   {'ara': 'Arabic'}               Qatar
# 249                   {'fra': 'French'}               Gabon
#
# [250 rows x 3 columns]
# Table 'LanguagesCountries' created successfully.
# {'Romanian': ['Moldova']}
# {'Romanian': ['Moldova'], 'English': ['United States']}
# {'Romanian': ['Moldova'], 'English': ['United States'], 'French': ['Mayotte']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru'], 'French': ['Mayotte']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru'], 'French': ['Mayotte'], 'Nauru': ['Nauru']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru'], 'French': ['Mayotte'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru'], 'French': ['Mayotte'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru'], 'French': ['Mayotte'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia'], 'Somali': ['Somalia']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom'], 'French': ['Mayotte', 'Equatorial Guinea'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa'], 'Zulu': ['South Africa']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa'], 'Zulu': ['South Africa']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa'], 'Zulu': ['South Africa']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa'], 'Zulu': ['South Africa'], 'Croatian': ['Croatia']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar', 'Martinique'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa'], 'Zulu': ['South Africa'], 'Croatian': ['Croatia']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa', 'Sierra Leone'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar', 'Martinique'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa'], 'Zulu': ['South Africa'], 'Croatian': ['Croatia']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa', 'Sierra Leone'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar', 'Martinique'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa'], 'Zulu': ['South Africa'], 'Croatian': ['Croatia'], 'Carolinian': ['Northern Mariana Islands']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa', 'Sierra Leone'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar', 'Martinique'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa'], 'Zulu': ['South Africa'], 'Croatian': ['Croatia'], 'Carolinian': ['Northern Mariana Islands'], 'Chamorro': ['Northern Mariana Islands']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa', 'Sierra Leone', 'Northern Mariana Islands'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar', 'Martinique'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa'], 'Zulu': ['South Africa'], 'Croatian': ['Croatia'], 'Carolinian': ['Northern Mariana Islands'], 'Chamorro': ['Northern Mariana Islands']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa', 'Sierra Leone', 'Northern Mariana Islands', 'Rwanda'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar', 'Martinique'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa'], 'Zulu': ['South Africa'], 'Croatian': ['Croatia'], 'Carolinian': ['Northern Mariana Islands'], 'Chamorro': ['Northern Mariana Islands']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa', 'Sierra Leone', 'Northern Mariana Islands', 'Rwanda'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar', 'Martinique', 'Rwanda'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa'], 'Zulu': ['South Africa'], 'Croatian': ['Croatia'], 'Carolinian': ['Northern Mariana Islands'], 'Chamorro': ['Northern Mariana Islands']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa', 'Sierra Leone', 'Northern Mariana Islands', 'Rwanda'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar', 'Martinique', 'Rwanda'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa'], 'Zulu': ['South Africa'], 'Croatian': ['Croatia'], 'Carolinian': ['Northern Mariana Islands'], 'Chamorro': ['Northern Mariana Islands'], 'Kinyarwanda': ['Rwanda']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa', 'Sierra Leone', 'Northern Mariana Islands', 'Rwanda'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar', 'Martinique', 'Rwanda'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria', 'Syria'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa'], 'Zulu': ['South Africa'], 'Croatian': ['Croatia'], 'Carolinian': ['Northern Mariana Islands'], 'Chamorro': ['Northern Mariana Islands'], 'Kinyarwanda': ['Rwanda']}
# {'Romanian': ['Moldova'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa', 'Sierra Leone', 'Northern Mariana Islands', 'Rwanda', 'Saint Vincent and the Grenadines'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar', 'Martinique', 'Rwanda'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay'], 'Albanian': ['Albania'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria', 'Syria'], 'Somali': ['Somalia'], 'Malay': ['Malaysia'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus'], 'Turkish': ['Cyprus'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka'], 'Afrikaans': ['South Africa'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa'], 'Tswana': ['South Africa'], 'Tsonga': ['South Africa'], 'Venda': ['South Africa'], 'Xhosa': ['South Africa'], 'Zulu': ['South Africa'], 'Croatian': ['Croatia'], 'Carolinian': ['Northern Mariana Islands'], 'Chamorro': ['Northern Mariana Islands'], 'Kinyarwanda': ['Rwanda']}
# ...
# {'Romanian': ['Moldova', 'Romania'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa', 'Sierra Leone', 'Northern Mariana Islands', 'Rwanda', 'Saint Vincent and the Grenadines', 'Saint Lucia', 'Tuvalu', 'Liberia', 'Heard Island and McDonald Islands', 'Guernsey', 'Fiji', 'Falkland Islands', 'Cocos (Keeling) Islands', 'Tokelau', 'Barbados', 'Cameroon', 'Kenya', 'Malta', 'Gibraltar', 'South Sudan', 'Puerto Rico', 'South Georgia', 'Botswana', 'British Indian Ocean Territory', 'Hong Kong', 'American Samoa', 'Solomon Islands', 'Eritrea', 'Pitcairn Islands', 'Montserrat', 'Philippines', 'Vanuatu', 'Saint Kitts and Nevis', 'Zimbabwe', 'Jersey', 'Caribbean Netherlands', 'Guyana', 'United States Minor Outlying Islands', 'Papua New Guinea', 'Zambia', 'Trinidad and Tobago', 'Sudan', 'India', 'Tanzania', 'Canada', 'Cayman Islands', 'Eswatini', 'Samoa', 'Bahamas', 'Tonga', 'Marshall Islands', 'Turks and Caicos Islands', 'Isle of Man', 'Norfolk Island', 'Cook Islands', 'Christmas Island', 'Saint Helena, Ascension and Tristan da Cunha', 'Anguilla', 'Micronesia', 'Guam', 'Kiribati', 'Sint Maarten', 'Jamaica', 'Lesotho', 'Australia', 'Grenada', 'Ghana', 'Seychelles', 'Bermuda', 'Pakistan', 'Curaçao', 'New Zealand', 'Belize', 'Uganda', 'Singapore', 'Namibia', 'Mauritius', 'Malawi'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar', 'Martinique', 'Rwanda', 'Guernsey', 'Central African Republic', 'Djibouti', 'New Caledonia', 'Cameroon', 'Saint Barthélemy', 'Monaco', 'France', 'Niger', 'Ivory Coast', 'Belgium', 'Burkina Faso', 'Saint Martin', 'Vanuatu', 'Jersey', 'Lebanon', 'French Southern and Antarctic Lands', 'Saint Pierre and Miquelon', 'Senegal', 'Canada', 'Switzerland', 'Republic of the Congo', 'Luxembourg', 'Togo', 'Wallis and Futuna', 'Réunion', 'Burundi', 'Haiti', 'Sint Maarten', 'French Guiana', 'Seychelles', 'Mali', 'Guadeloupe', 'Comoros', 'Mauritius', 'French Polynesia', 'DR Congo', 'Guinea', 'Chad', 'Benin'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea', 'São Tomé and Príncipe', 'Guinea-Bissau', 'Portugal', 'Angola', 'Timor-Leste', 'Macau'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay', 'Honduras', 'Argentina', 'Mexico', 'Guatemala', 'Puerto Rico', 'El Salvador', 'Cuba', 'Bolivia', 'Peru', 'Costa Rica', 'Colombia', 'Venezuela', 'Panama', 'Uruguay', 'Nicaragua', 'Guam', 'Spain', 'Chile', 'Belize', 'Ecuador', 'Dominican Republic'], 'Albanian': ['Albania', 'Kosovo'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria', 'Syria', 'Jordan', 'Mauritania', 'Djibouti', 'Morocco', 'United Arab Emirates', 'Tunisia', 'Eritrea', 'Lebanon', 'Sudan', 'Oman', 'Bahrain', 'Israel', 'Libya', 'Palestine', 'Saudi Arabia', 'Comoros', 'Egypt', 'Chad', 'Iraq'], 'Somali': ['Somalia'], 'Malay': ['Malaysia', 'Brunei', 'Singapore'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara', 'Morocco'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus', 'Greece'], 'Turkish': ['Cyprus', 'Turkey'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay', 'Argentina', 'Bolivia'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka', 'India', 'Singapore'], 'Afrikaans': ['South Africa', 'Namibia'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa', 'Eswatini'], 'Tswana': ['South Africa', 'Botswana', 'Zimbabwe', 'Namibia'], 'Tsonga': ['South Africa', 'Zimbabwe'], 'Venda': ['South Africa', 'Zimbabwe'], 'Xhosa': ['South Africa', 'Zimbabwe'], 'Zulu': ['South Africa'], 'Croatian': ['Croatia', 'Bosnia and Herzegovina'], 'Carolinian': ['Northern Mariana Islands'], 'Chamorro': ['Northern Mariana Islands', 'Guam'], 'Kinyarwanda': ['Rwanda'], 'Serbian': ['Kosovo', 'Bosnia and Herzegovina', 'Serbia'], 'Tuvaluan': ['Tuvalu'], 'Ne ...
# {'Romanian': ['Moldova', 'Romania'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa', 'Sierra Leone', 'Northern Mariana Islands', 'Rwanda', 'Saint Vincent and the Grenadines', 'Saint Lucia', 'Tuvalu', 'Liberia', 'Heard Island and McDonald Islands', 'Guernsey', 'Fiji', 'Falkland Islands', 'Cocos (Keeling) Islands', 'Tokelau', 'Barbados', 'Cameroon', 'Kenya', 'Malta', 'Gibraltar', 'South Sudan', 'Puerto Rico', 'South Georgia', 'Botswana', 'British Indian Ocean Territory', 'Hong Kong', 'American Samoa', 'Solomon Islands', 'Eritrea', 'Pitcairn Islands', 'Montserrat', 'Philippines', 'Vanuatu', 'Saint Kitts and Nevis', 'Zimbabwe', 'Jersey', 'Caribbean Netherlands', 'Guyana', 'United States Minor Outlying Islands', 'Papua New Guinea', 'Zambia', 'Trinidad and Tobago', 'Sudan', 'India', 'Tanzania', 'Canada', 'Cayman Islands', 'Eswatini', 'Samoa', 'Bahamas', 'Tonga', 'Marshall Islands', 'Turks and Caicos Islands', 'Isle of Man', 'Norfolk Island', 'Cook Islands', 'Christmas Island', 'Saint Helena, Ascension and Tristan da Cunha', 'Anguilla', 'Micronesia', 'Guam', 'Kiribati', 'Sint Maarten', 'Jamaica', 'Lesotho', 'Australia', 'Grenada', 'Ghana', 'Seychelles', 'Bermuda', 'Pakistan', 'Curaçao', 'New Zealand', 'Belize', 'Uganda', 'Singapore', 'Namibia', 'Mauritius', 'Malawi'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar', 'Martinique', 'Rwanda', 'Guernsey', 'Central African Republic', 'Djibouti', 'New Caledonia', 'Cameroon', 'Saint Barthélemy', 'Monaco', 'France', 'Niger', 'Ivory Coast', 'Belgium', 'Burkina Faso', 'Saint Martin', 'Vanuatu', 'Jersey', 'Lebanon', 'French Southern and Antarctic Lands', 'Saint Pierre and Miquelon', 'Senegal', 'Canada', 'Switzerland', 'Republic of the Congo', 'Luxembourg', 'Togo', 'Wallis and Futuna', 'Réunion', 'Burundi', 'Haiti', 'Sint Maarten', 'French Guiana', 'Seychelles', 'Mali', 'Guadeloupe', 'Comoros', 'Mauritius', 'French Polynesia', 'DR Congo', 'Guinea', 'Chad', 'Benin'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea', 'São Tomé and Príncipe', 'Guinea-Bissau', 'Portugal', 'Angola', 'Timor-Leste', 'Macau'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay', 'Honduras', 'Argentina', 'Mexico', 'Guatemala', 'Puerto Rico', 'El Salvador', 'Cuba', 'Bolivia', 'Peru', 'Costa Rica', 'Colombia', 'Venezuela', 'Panama', 'Uruguay', 'Nicaragua', 'Guam', 'Spain', 'Chile', 'Belize', 'Ecuador', 'Dominican Republic'], 'Albanian': ['Albania', 'Kosovo'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria', 'Syria', 'Jordan', 'Mauritania', 'Djibouti', 'Morocco', 'United Arab Emirates', 'Tunisia', 'Eritrea', 'Lebanon', 'Sudan', 'Oman', 'Bahrain', 'Israel', 'Libya', 'Palestine', 'Saudi Arabia', 'Comoros', 'Egypt', 'Chad', 'Iraq', 'Qatar'], 'Somali': ['Somalia'], 'Malay': ['Malaysia', 'Brunei', 'Singapore'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara', 'Morocco'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus', 'Greece'], 'Turkish': ['Cyprus', 'Turkey'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay', 'Argentina', 'Bolivia'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka', 'India', 'Singapore'], 'Afrikaans': ['South Africa', 'Namibia'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa', 'Eswatini'], 'Tswana': ['South Africa', 'Botswana', 'Zimbabwe', 'Namibia'], 'Tsonga': ['South Africa', 'Zimbabwe'], 'Venda': ['South Africa', 'Zimbabwe'], 'Xhosa': ['South Africa', 'Zimbabwe'], 'Zulu': ['South Africa'], 'Croatian': ['Croatia', 'Bosnia and Herzegovina'], 'Carolinian': ['Northern Mariana Islands'], 'Chamorro': ['Northern Mariana Islands', 'Guam'], 'Kinyarwanda': ['Rwanda'], 'Serbian': ['Kosovo', 'Bosnia and Herzegovina', 'Serbia'], 'Tuvaluan': ['Tuva ...
# {'Romanian': ['Moldova', 'Romania'], 'English': ['United States', 'Nauru', 'United States Virgin Islands', 'Niue', 'Palau', 'Nigeria', 'British Virgin Islands', 'Gambia', 'Malaysia', 'Dominica', 'United Kingdom', 'Antigua and Barbuda', 'Ireland', 'South Africa', 'Sierra Leone', 'Northern Mariana Islands', 'Rwanda', 'Saint Vincent and the Grenadines', 'Saint Lucia', 'Tuvalu', 'Liberia', 'Heard Island and McDonald Islands', 'Guernsey', 'Fiji', 'Falkland Islands', 'Cocos (Keeling) Islands', 'Tokelau', 'Barbados', 'Cameroon', 'Kenya', 'Malta', 'Gibraltar', 'South Sudan', 'Puerto Rico', 'South Georgia', 'Botswana', 'British Indian Ocean Territory', 'Hong Kong', 'American Samoa', 'Solomon Islands', 'Eritrea', 'Pitcairn Islands', 'Montserrat', 'Philippines', 'Vanuatu', 'Saint Kitts and Nevis', 'Zimbabwe', 'Jersey', 'Caribbean Netherlands', 'Guyana', 'United States Minor Outlying Islands', 'Papua New Guinea', 'Zambia', 'Trinidad and Tobago', 'Sudan', 'India', 'Tanzania', 'Canada', 'Cayman Islands', 'Eswatini', 'Samoa', 'Bahamas', 'Tonga', 'Marshall Islands', 'Turks and Caicos Islands', 'Isle of Man', 'Norfolk Island', 'Cook Islands', 'Christmas Island', 'Saint Helena, Ascension and Tristan da Cunha', 'Anguilla', 'Micronesia', 'Guam', 'Kiribati', 'Sint Maarten', 'Jamaica', 'Lesotho', 'Australia', 'Grenada', 'Ghana', 'Seychelles', 'Bermuda', 'Pakistan', 'Curaçao', 'New Zealand', 'Belize', 'Uganda', 'Singapore', 'Namibia', 'Mauritius', 'Malawi'], 'French': ['Mayotte', 'Equatorial Guinea', 'Madagascar', 'Martinique', 'Rwanda', 'Guernsey', 'Central African Republic', 'Djibouti', 'New Caledonia', 'Cameroon', 'Saint Barthélemy', 'Monaco', 'France', 'Niger', 'Ivory Coast', 'Belgium', 'Burkina Faso', 'Saint Martin', 'Vanuatu', 'Jersey', 'Lebanon', 'French Southern and Antarctic Lands', 'Saint Pierre and Miquelon', 'Senegal', 'Canada', 'Switzerland', 'Republic of the Congo', 'Luxembourg', 'Togo', 'Wallis and Futuna', 'Réunion', 'Burundi', 'Haiti', 'Sint Maarten', 'French Guiana', 'Seychelles', 'Mali', 'Guadeloupe', 'Comoros', 'Mauritius', 'French Polynesia', 'DR Congo', 'Guinea', 'Chad', 'Benin', 'Gabon'], 'Nauru': ['Nauru'], 'Portuguese': ['Mozambique', 'Brazil', 'Cape Verde', 'Equatorial Guinea', 'São Tomé and Príncipe', 'Guinea-Bissau', 'Portugal', 'Angola', 'Timor-Leste', 'Macau'], 'Spanish': ['Equatorial Guinea', 'Western Sahara', 'Paraguay', 'Honduras', 'Argentina', 'Mexico', 'Guatemala', 'Puerto Rico', 'El Salvador', 'Cuba', 'Bolivia', 'Peru', 'Costa Rica', 'Colombia', 'Venezuela', 'Panama', 'Uruguay', 'Nicaragua', 'Guam', 'Spain', 'Chile', 'Belize', 'Ecuador', 'Dominican Republic'], 'Albanian': ['Albania', 'Kosovo'], 'Niuean': ['Niue'], 'Palauan': ['Palau'], 'Arabic': ['Somalia', 'Yemen', 'Kuwait', 'Algeria', 'Syria', 'Jordan', 'Mauritania', 'Djibouti', 'Morocco', 'United Arab Emirates', 'Tunisia', 'Eritrea', 'Lebanon', 'Sudan', 'Oman', 'Bahrain', 'Israel', 'Libya', 'Palestine', 'Saudi Arabia', 'Comoros', 'Egypt', 'Chad', 'Iraq', 'Qatar'], 'Somali': ['Somalia'], 'Malay': ['Malaysia', 'Brunei', 'Singapore'], 'Malagasy': ['Madagascar'], 'Berber': ['Western Sahara', 'Morocco'], 'Hassaniya': ['Western Sahara'], 'Greek': ['Cyprus', 'Greece'], 'Turkish': ['Cyprus', 'Turkey'], 'Irish': ['Ireland'], 'Guaraní': ['Paraguay', 'Argentina', 'Bolivia'], 'Sinhala': ['Sri Lanka'], 'Tamil': ['Sri Lanka', 'India', 'Singapore'], 'Afrikaans': ['South Africa', 'Namibia'], 'Southern Ndebele': ['South Africa'], 'Northern Sotho': ['South Africa'], 'Southern Sotho': ['South Africa'], 'Swazi': ['South Africa', 'Eswatini'], 'Tswana': ['South Africa', 'Botswana', 'Zimbabwe', 'Namibia'], 'Tsonga': ['South Africa', 'Zimbabwe'], 'Venda': ['South Africa', 'Zimbabwe'], 'Xhosa': ['South Africa', 'Zimbabwe'], 'Zulu': ['South Africa'], 'Croatian': ['Croatia', 'Bosnia and Herzegovina'], 'Carolinian': ['Northern Mariana Islands'], 'Chamorro': ['Northern Mariana Islands', 'Guam'], 'Kinyarwanda': ['Rwanda'], 'Serbian': ['Kosovo', 'Bosnia and Herzegovina', 'Serbia'], 'Tuvaluan ...
# Data inserted into 'LanguagesCountries' successfully.
# /var/folders/qx/_jjs26m91dx5hnhwzqmp8xbm0000gp/T/ipykernel_46616/4293510471.py:20: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_filtered = df.applymap(replace_empty_list)
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[88], line 18
#      13     process_data(url, 'LanguagesCountries', ['languages', 'country'], additional_processing=process_languages_countries)
#      16 #get_countries()
#      17 #get_independent_countries()
# ---> 18 get_languages_countries()
#
# Cell In[88], line 13, in get_languages_countries()
#      11 def get_languages_countries():
#      12     url = 'https://restcountries.com/v3.1/all?fields=name,languages'
# ---> 13     process_data(url, 'LanguagesCountries', ['languages', 'country'], additional_processing=process_languages_countries)
#
# Cell In[86], line 57, in process_data(url, table_name, columns, additional_processing)
#      55     if additional_processing:
#      56         additional_processing(df)
# ---> 57     insert_data(table_name, df.values.tolist())
#      58 else:
#      59     print(f"Failed to fetch data from {url}.")
#
# Cell In[86], line 43, in insert_data(table_name, data, db_name)
#      41 placeholders = ', '.join(['?'] * len(data[0]))
#      42 for row in data:
# ---> 43     cursor.execute(f'INSERT INTO "{table_name}" VALUES ({placeholders})', row)
#      44 conn.commit()
#      45 conn.close()
#
# ProgrammingError: Error binding parameter 1: type 'dict' is not supported
